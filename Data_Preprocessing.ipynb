# %%
#Importing important libraries
import pandas as pd
import numpy as np

# %%
#Mouting dataset file
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #STEP 1 :- Data Understanding

# %%
#Reading datset in csv format.
df = pd.read_csv("/content/drive/MyDrive/student-dropout/data.csv",sep=";")

#Getting first five rows
df.head()
# Out:
#    Marital status  Application mode  ...   GDP    Target
# 0               1                17  ...  1.74   Dropout
# 1               1                15  ...  0.79  Graduate
# 2               1                 1  ...  1.74   Dropout
# 3               1                17  ... -3.12  Graduate
# 4               2                39  ...  0.79  Graduate
#
# [5 rows x 37 columns]

# %%
#Checking number of Rows & Columns.
df.shape
# Out:
# (4424, 37)

# %%
df.columns.tolist()
# Out:
# ['Marital status',
#  'Application mode',
#  'Application order',
#  'Course',
#  'Daytime/evening attendance\t',
#  'Previous qualification',
#  'Previous qualification (grade)',
#  'Nacionality',
#  "Mother's qualification",
#  "Father's qualification",
#  "Mother's occupation",
#  "Father's occupation",
#  'Admission grade',
#  'Displaced',
#  'Educational special needs',
#  'Debtor',
#  'Tuition fees up to date',
#  'Gender',
#  'Scholarship holder',
#  'Age at enrollment',
#  'International',
#  'Curricular units 1st sem (credited)',
#  'Curricular units 1st sem (enrolled)',
#  'Curricular units 1st sem (evaluations)',
#  'Curricular units 1st sem (approved)',
#  'Curricular units 1st sem (grade)',
#  'Curricular units 1st sem (without evaluations)',
#  'Curricular units 2nd sem (credited)',
#  'Curricular units 2nd sem (enrolled)',
#  'Curricular units 2nd sem (evaluations)',
#  'Curricular units 2nd sem (approved)',
#  'Curricular units 2nd sem (grade)',
#  'Curricular units 2nd sem (without evaluations)',
#  'Unemployment rate',
#  'Inflation rate',
#  'GDP',
#  'Target']

# %%
#checking overall information of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4424 non-null   int64
#  9   Father's qualification                          4424 non-null   int64
#  10  Mother's occupation                             4424 non-null   int64
#  11  Father's occupation                             4424 non-null   int64
#  12  Admission grade                                 4424 non-null   float64
#  13  Displaced                                       4424 non-null   int64
#  14  Educational special needs                       4424 non-null   int64
#  15  Debtor                                          4424 non-null   int64
#  16  Tuition fees up to date                         4424 non-null   int64
#  17  Gender                                          4424 non-null   int64
#  18  Scholarship holder                              4424 non-null   int64
#  19  Age at enrollment                               4424 non-null   int64
#  20  International                                   4424 non-null   int64
#  21  Curricular units 1st sem (credited)             4424 non-null   int64
#  22  Curricular units 1st sem (enrolled)             4424 non-null   int64
#  23  Curricular units 1st sem (evaluations)          4424 non-null   int64
#  24  Curricular units 1st sem (approved)             4424 non-null   int64
#  25  Curricular units 1st sem (grade)                4424 non-null   float64
#  26  Curricular units 1st sem (without evaluations)  4424 non-null   int64
#  27  Curricular units 2nd sem (credited)             4424 non-null   int64
#  28  Curricular units 2nd sem (enrolled)             4424 non-null   int64
#  29  Curricular units 2nd sem (evaluations)          4424 non-null   int64
#  30  Curricular units 2nd sem (approved)             4424 non-null   int64
#  31  Curricular units 2nd sem (grade)                4424 non-null   float64
#  32  Curricular units 2nd sem (without evaluations)  4424 non-null   int64
#  33  Unemployment rate                               4424 non-null   float64
#  34  Inflation rate                                  4424 non-null   float64
#  35  GDP                                             4424 non-null   float64
#  36  Target                                          4424 non-null   object
# dtypes: float64(7), int64(29), object(1)
# memory usage: 1.2+ MB

# %%
#Checking for null or missing values
df.isnull().sum()
# Out:
# Marital status                                    0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Daytime/evening attendance\t                      0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Nacionality                                       0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# Age at enrollment                                 0
# International                                     0
# Curricular units 1st sem (credited)               0
# Curricular units 1st sem (enrolled)               0
# Curricular units 1st sem (evaluations)            0
# Curricular units 1st sem (approved)               0
# Curricular units 1st sem (grade)                  0
# Curricular units 1st sem (without evaluations)    0
# Curricular units 2nd sem (credited)               0
# Curricular units 2nd sem (enrolled)               0
# Curricular units 2nd sem (evaluations)            0
# Curricular units 2nd sem (approved)               0
# Curricular units 2nd sem (grade)                  0
# Curricular units 2nd sem (without evaluations)    0
# Unemployment rate                                 0
# Inflation rate                                    0
# GDP                                               0
# Target                                            0
# dtype: int64

# %%
#Describing Statistical data
df.describe()
# Out:
#        Marital status  Application mode  ...  Inflation rate          GDP
# count     4424.000000       4424.000000  ...     4424.000000  4424.000000
# mean         1.178571         18.669078  ...        1.228029     0.001969
# std          0.605747         17.484682  ...        1.382711     2.269935
# min          1.000000          1.000000  ...       -0.800000    -4.060000
# 25%          1.000000          1.000000  ...        0.300000    -1.700000
# 50%          1.000000         17.000000  ...        1.400000     0.320000
# 75%          1.000000         39.000000  ...        2.600000     1.790000
# max          6.000000         57.000000  ...        3.700000     3.510000
#
# [8 rows x 36 columns]

# %%
#Getting Count of Target values
df["Target"].value_counts()
# Out:
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Marital status  Application mode  ...   GDP    Target
# 0               1                17  ...  1.74   Dropout
# 1               1                15  ...  0.79  Graduate
# 2               1                 1  ...  1.74   Dropout
# 3               1                17  ... -3.12  Graduate
# 4               2                39  ...  0.79  Graduate
#
# [5 rows x 37 columns]

# %%
#Dropping useless columns
drop_cols = ["Mother's qualification","Mother's occupation","Father's occupation","Father's qualification","Nacionality","Application mode","Application order","Curricular units 1st sem (without evaluations)","Curricular units 2nd sem (without evaluations)"]
df = df.drop(columns=drop_cols)

# %%
#Checking for unique values in each column
df.nunique()
# Out:
# Marital status                              6
# Course                                     17
# Daytime/evening attendance\t                2
# Previous qualification                     17
# Previous qualification (grade)            101
# Admission grade                           620
# Displaced                                   2
# Educational special needs                   2
# Debtor                                      2
# Tuition fees up to date                     2
# Gender                                      2
# Scholarship holder                          2
# Age at enrollment                          46
# International                               2
# Curricular units 1st sem (credited)        21
# Curricular units 1st sem (enrolled)        23
# Curricular units 1st sem (evaluations)     35
# Curricular units 1st sem (approved)        23
# Curricular units 1st sem (grade)          805
# Curricular units 2nd sem (credited)        19
# Curricular units 2nd sem (enrolled)        22
# Curricular units 2nd sem (evaluations)     30
# Curricular units 2nd sem (approved)        20
# Curricular units 2nd sem (grade)          786
# Unemployment rate                          10
# Inflation rate                              9
# GDP                                        10
# Target                                      3
# dtype: int64

# %%
df.head()
# Out:
#    Marital status  Course  ...   GDP    Target
# 0               1     171  ...  1.74   Dropout
# 1               1    9254  ...  0.79  Graduate
# 2               1    9070  ...  1.74   Dropout
# 3               1    9773  ... -3.12  Graduate
# 4               2    8014  ...  0.79  Graduate
#
# [5 rows x 28 columns]

# %% [markdown]
# **COLUMN DESCRIPTION **
#
# **1** **Marital Status**: 1 – single, 2 – married, 3 – widower, 4 – divorced, 5 – facto union, 6 – legally separated.
#
#
# **2** **Course**: 33 - Biofuel Production Technologies, 171 - Animation and Multimedia Design, 8014 - Social Service, 9003 - Agronomy, 9070 - Communication Design, 9085 - Veterinary Nursing, 9119 - Informatics Engineering, 9130 - Equinculture, 9147 - Management, 9238 - Social Service, 9254 - Tourism, 9500 - Nursing, 9556 - Oral Hygiene, 9670 - Advertising and Marketing Management, 9773 - Journalism and Communication, 9853 - Basic Education, 9991 - Management.
#
# **3** **Daytime/evening attendance**: 1 – daytime ,0 - evening.
#
# **4** **Previous qualification**: 1 - Secondary education, 2 - Higher education - bachelor's degree, 3 - Higher education - degree, 4 - Higher education - master's, 5 - Higher education - doctorate, 6 - Frequency of higher education, 9 - 12th year of schooling - not completed, 10 - 11th year of schooling - not completed, 12 - Other - 11th year of schooling ,14 - 10th year of schooling ,15 - 10th year of schooling - not completed, 19 - Basic education 3rd cycle (9th/10th/11th year) or equiv, 38 - Basic education 2nd cycle (6th/7th/8th year) or equiv, 39 - Technological specialization course, 40 - Higher education - degree (1st cycle), 42 - Professional higher technical course, 43 - Higher education - master (2nd cycle).
#
# **5** **Previous qualification (grade)** : Grade of previous qualification (between 0 and 200)
#
# **6** **Admission grade**: Admission grade (between 0 and 200).
#
# **7** **Displaced**: 	1 – yes, 0 – no.
#
# **8** **Educational special needs**: 	1 – yes, 0 – no.
#
# **9** **Debtor**: 1 – yes, 0 – no.
#
# **10** **Tuition fees up to date**: 1 – yes, 0 – no.
#
# **11** **Gender**: 1 – male, 0 – female
#
# **12** **Scholarship holder**:  1 – yes, 0 – no.
#
# **13** **International**:  1 – yes, 0 – no.
#
# **14** **Curricular units 1st sem (grade)**: Grade average in the 1st semester (between 0 and 20)
#
# **15** **Curricular units 2nd sem (grade)**: Grade average in the 2nd semester (between 0 and 20)

# %% [markdown]
# #STEP 2 :- Exploratory Data Analysis(Visualization)

# %%
df.head()
# Out:
#    Marital status  Course  ...   GDP    Target
# 0               1     171  ...  1.74   Dropout
# 1               1    9254  ...  0.79  Graduate
# 2               1    9070  ...  1.74   Dropout
# 3               1    9773  ... -3.12  Graduate
# 4               2    8014  ...  0.79  Graduate
#
# [5 rows x 28 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Subplot
plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
sns.countplot(x="Target",data=df)
plt.title("Target Distribuition")

plt.subplot(2,2,2)
sns.boxplot(y="Admission grade",data=df)
plt.title("BOXPLOT:-Admission grade")

plt.subplot(2,2,3)
sns.countplot(x="Marital status",data=df)
plt.title("Distribuition of Marital status")

plt.subplot(2,2,4)
sns.countplot(x="Course",data=df)
plt.xticks(rotation=45, ha="right")
plt.title('Distribuition of Course')

plt.show()

# %% [markdown]
# Above Visualization Descriptions:-
#
#
# **1]Target Distribuition** : Graduate% > Dropout% > Enrolled.
#
# **2]BOXPLOT:-Admission grade** : Outlier Detection Of Column Admission Grade.
#
# **3]Distribuition of Marital status** : People Who are Singel Have High Rate.
#
# **4]Distribuition of Course** : Course 9500 means Nursing students Have Higher Rate.

# %% [markdown]
# Bivariate Analysis

# %%
#CountPlot - Course categorized by Target
sns.countplot(x="Course",hue="Target",data=df)
plt.title("Course categorized by Target")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The above chart shows how students are distributed across different courses and their academic outcomes. It highlights courses where dropout rates are higher compared to others, and also shows which courses produce more graduates.
#
#
# 9500(Nursing) Course produce more graduated.

# %%
#CountPlot - Gender categorized by Target
sns.countplot(x="Gender",hue="Target",data=df)
plt.title("Gender categorized by Target")
plt.show()

# %% [markdown]
# The above  plot compares male and female students in terms of dropout, enrollment, and graduation rates. It helps identify whether dropout is more common in one gender compared to the other.

# %%
#BoxPlot - Age at Enrollment vs Dropout
plt.figure(figsize=(8,5))
sns.boxplot(x="Target", y="Age at enrollment", data=df)
plt.title("Age at Enrollment vs Dropout")
plt.show()

# %% [markdown]
# The above plot shows how student age at the time of enrollment influences their academic outcomes. If dropout students are generally older than graduates, it indicates that age might be a risk factor for dropout.

# %%
#Heatmap - Correlation Heatmap Of Numerical Features
plt.figure(figsize=(15, 10))
corr = df.select_dtypes(include=np.number).corr()
sns.heatmap(corr,annot=True,cmap="coolwarm",fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py:61: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# The correlation heatmap highlights strong relationships between academic performance indicators such as grades and dropout likelihood, while demographic features show weaker correlations. This suggests that academic results play a more significant role in predicting student outcomes.

# %% [markdown]
# #STEP 3 :- Data Preprocessing

# %% [markdown]
# Data preprocessing is the process of cleaning and transforming raw data into a format suitable for modeling. It improves model performance and ensures reliable predictions

# %% [markdown]
# #### Encoding Categorical Variables
# Machine learning models cannot directly understand categorical (text) data.
# Therefore, we need to convert categorical columns into numerical values.
#
# In this project, we are using **Label Encoding** with Target Column.

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
df["Target"] = LE.fit_transform(df["Target"])

# %% [markdown]
# #####Target Column Description
#
# Dropped → 0
#
# Enrolled → 1
#
# Graduated → 2

# %%
df["Target"]
# Out:
# 0       0
# 1       2
# 2       0
# 3       2
# 4       2
#        ..
# 4419    2
# 4420    0
# 4421    0
# 4422    2
# 4423    2
# Name: Target, Length: 4424, dtype: int64

# %% [markdown]
# #### Feature Scaling
# The dataset contains numerical features with different ranges.
# Without scaling, features with larger values may dominate smaller ones and affect model performance.
#
# To overcome this, we will apply **Standard scaling** with Mean = 0, Std = 1 so that all numerical features are brought to a similar scale.
# This improves the training process and ensures fair contribution of each feature.

# %%
#Splitting Features and target

#Features
X = df.drop("Target",axis=1)
X.head()
# Out:
#    Marital status  Course  ...  Inflation rate   GDP
# 0               1     171  ...             1.4  1.74
# 1               1    9254  ...            -0.3  0.79
# 2               1    9070  ...             1.4  1.74
# 3               1    9773  ...            -0.8 -3.12
# 4               2    8014  ...            -0.3  0.79
#
# [5 rows x 27 columns]

# %%
#Target

Y = df["Target"]
Y.head()
# Out:
# 0    0
# 1    2
# 2    0
# 3    2
# 4    2
# Name: Target, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[-0.29482875, -4.20952017,  0.35008246, ..., -0.28763846,
#          0.12438647,  0.76576084],
#        [-0.29482875,  0.19258032,  0.35008246, ...,  0.87622207,
#         -1.10522155,  0.34719942],
#        [-0.29482875,  0.10340423,  0.35008246, ..., -0.28763846,
#          0.12438647,  0.76576084],
#        ...,
#        [-0.29482875,  0.31180489,  0.35008246, ...,  0.87622207,
#         -1.10522155,  0.34719942],
#        [-0.29482875,  0.14072248,  0.35008246, ..., -0.81325289,
#         -1.46687097, -1.37551124],
#        [-0.29482875,  0.44411507,  0.35008246, ...,  0.42569541,
#          1.7879738 , -0.74987207]])

# %%
X_scaled = pd.DataFrame(X,columns=df.columns[:-1])
X_scaled.head()
# Out:
#    Marital status    Course  ...  Inflation rate       GDP
# 0       -0.294829 -4.209520  ...        0.124386  0.765761
# 1       -0.294829  0.192580  ...       -1.105222  0.347199
# 2       -0.294829  0.103404  ...        0.124386  0.765761
# 3       -0.294829  0.444115  ...       -1.466871 -1.375511
# 4        1.356212 -0.408389  ...       -1.105222  0.347199
#
# [5 rows x 27 columns]
